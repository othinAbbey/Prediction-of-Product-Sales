# %% [markdown]
# <a href="https://colab.research.google.com/github/othinAbbey/Prediction-of-Product-Sales/blob/main/Onyango_Abbey_Project_1_Part_2_(Core).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Loading Data

# %%
import pandas as pd
import numpy as np

# %%
fpath = "/content/drive/MyDrive/Course 1/Week 2/Data Folder/sales_predictions_2023.csv"
sales_prediction = pd.read_csv(fpath)

# %%
sales_prediction.info()
sales_prediction.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            8523 non-null   object
#  1   Item_Weight                7060 non-null   float64
#  2   Item_Fat_Content           8523 non-null   object
#  3   Item_Visibility            8523 non-null   float64
#  4   Item_Type                  8523 non-null   object
#  5   Item_MRP                   8523 non-null   float64
#  6   Outlet_Identifier          8523 non-null   object
#  7   Outlet_Establishment_Year  8523 non-null   int64
#  8   Outlet_Size                6113 non-null   object
#  9   Outlet_Location_Type       8523 non-null   object
#  10  Outlet_Type                8523 non-null   object
#  11  Item_Outlet_Sales          8523 non-null   float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 799.2+ KB
# ...

# %% [markdown]
# #Data Cleaning

# %% [markdown]
# ## DataTypes

# %%
sales_prediction.dtypes
# Out:
# Item_Identifier               object
# Item_Weight                  float64
# Item_Fat_Content              object
# Item_Visibility              float64
# Item_Type                     object
# Item_MRP                     float64
# Outlet_Identifier             object
# Outlet_Establishment_Year      int64
# Outlet_Size                   object
# Outlet_Location_Type          object
# Outlet_Type                   object
# Item_Outlet_Sales            float64
# dtype: object

# %% [markdown]
# ##Data parameters

# %% [markdown]
# - Rows 8522
# - Columns 12

# %% [markdown]
# ##Duplicates

# %%
sales_prediction.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## Missing Data

# %%
sales_prediction.isnull().sum()
sales_prediction[['Item_Weight','Outlet_Size']] = sales_prediction[['Item_Weight','Outlet_Size']].fillna('MISSING')

# %%
#check if null values have been replaced
sales_prediction.isnull().sum()
# Out:
# Item_Identifier              0
# Item_Weight                  0
# Item_Fat_Content             0
# Item_Visibility              0
# Item_Type                    0
# Item_MRP                     0
# Outlet_Identifier            0
# Outlet_Establishment_Year    0
# Outlet_Size                  0
# Outlet_Location_Type         0
# Outlet_Type                  0
# Item_Outlet_Sales            0
# dtype: int64

# %% [markdown]
# ## Check For Inconsistancy

# %%
sales_prediction
# Out:
#      Item_Identifier Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15         9.3          Low Fat         0.016047
# 1              DRC01        5.92          Regular         0.019278
# 2              FDN15        17.5          Low Fat         0.016760
# 3              FDX07        19.2          Regular         0.000000
# 4              NCD19        8.93          Low Fat         0.000000
# ...              ...         ...              ...              ...
# 8518           FDF22       6.865          Low Fat         0.056783
# 8519           FDS36        8.38          Regular         0.046982
# 8520           NCJ29        10.6          Low Fat         0.035186
# 8521           FDN46        7.21          Regular         0.145221
# 8522           DRG01        14.8          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# ...

# %% [markdown]
# ## Numerical Columns

# %%
numerical_columns = sales_prediction.select_dtypes(include='number')
for column in numerical_columns:
  print(f'The minimum for {column} is {numerical_columns[column].min().round(2)}')
  print(f'The maximum for {column} is {numerical_columns[column].max().round(2)}')
  print(f'The mean for {column} is {numerical_columns[column].mean().round(2)}')
  print("\n")
# Out:
# The minimum for Item_Visibility is 0.0
# The maximum for Item_Visibility is 0.33
# The mean for Item_Visibility is 0.07
#
#
# The minimum for Item_MRP is 31.29
# The maximum for Item_MRP is 266.89
# The mean for Item_MRP is 140.99
#
#
# The minimum for Outlet_Establishment_Year is 1985
# The maximum for Outlet_Establishment_Year is 2009
# The mean for Outlet_Establishment_Year is 1997.83
#
#
# The minimum for Item_Outlet_Sales is 33.29
# The maximum for Item_Outlet_Sales is 13086.96
# The mean for Item_Outlet_Sales is 2181.29
